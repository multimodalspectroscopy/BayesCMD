# %%
"""Process comparison of healthy and impaired for PLOS."""
import os
import argparse
import sys
sys.path.append('..')
from bayescmd.results_handling import comparison_kde_plot
from bayescmd.results_handling import data_import
from bayescmd.abc import import_actual_data
from bayescmd.abc import priors_creator
from bayescmd.util import findBaseDir
import json
from distutils import dir_util

BASEDIR = os.path.abspath(findBaseDir('BayesCMD'))
# Out:
# STARTING AT: /home/buck06191/repos/GitHub/BayesCMD/bayescmd
#  Looking for: BayesCMD

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
healthy_Dir = "/home/buck06191/Dropbox/phd/PLOS_paper/data/parameters/healthy/wide_params/NRMSE_SA"
impaired_Dir = "/home/buck06191/Dropbox/phd/PLOS_paper/data/parameters/impaired/wide_params/NRMSE_SA"
healthy_pfile = os.path.abspath(os.path.join(healthy_Dir, 'all_parameters.csv'))
impaired_pfile = os.path.abspath(os.path.join(impaired_Dir, 'all_parameters.csv'))

config_file="../examples/configuration_files/varying_parameter_wide_config.json"
with open(config_file, 'r') as conf_f:
    conf = json.load(conf_f)
params = conf['priors']

healthy_input_path = os.path.join(BASEDIR,
                          'PLOS_paper',
                          'data',
                          'simulated_smooth_combined_ABP.csv')

healthy_d0 = import_actual_data(healthy_input_path)

impaired_input_path = os.path.join(BASEDIR,
                          'PLOS_paper',
                          'data',
                          'simulated_smooth_combined_impaired_ABP.csv')

impaired_d0 = import_actual_data(impaired_input_path)

targets = conf['targets']
model_name = conf['model_name']
inputs = conf['inputs']

config = {
    "model_name": model_name,
    "targets": targets,
    "inputs": inputs,
    "parameters": params,
    "input_path": healthy_input_path,
    "zero_flag": {k: False for k in targets}
}

results_healthy = data_import(healthy_pfile)
results_impaired = data_import(impaired_pfile)
# Out:
# Number of lines:	999000
# Number of NaN values:	0
# Number of lines:	999000
# Number of NaN values:	0

# %%
results_healthy.rename(columns={'NRMSE': 'NRMSE_mean', 'NRMSE_old': 'NRMSE_range'}, inplace=True)
results_healthy.to_csv(healthy_pfile)
results_impaired.rename(columns={'NRMSE': 'NRMSE_mean', 'NRMSE_old': 'NRMSE_range'}, inplace=True)
results_impaired.to_csv(impaired_pfile)

# %%
# %matplotlib inline

summed_impaired_mean = 0
summed_healthy_mean = 0

for sig in ['CCO', 'Vmca', 'TOI']:
    healthy_mean = np.mean(healthy_d0[sig])
    impaired_mean = np.mean(impaired_d0[sig])
    # print(healthy_rng)
    healthy_n = len(healthy_d0[sig])
    impaired_n = len(impaired_d0[sig])
    
    select_healthy = results_healthy[results_healthy['{}_euclidean'.format(sig)]!=100000]
    select_impaired = results_impaired[results_impaired['{}_euclidean'.format(sig)]!=100000]

    
    summed_healthy_mean += (1./healthy_mean * 1/np.sqrt(healthy_n) *  select_healthy['{}_euclidean'.format(sig)]).values
    summed_impaired_mean += (1./impaired_mean * 1/np.sqrt(impaired_n) *  select_impaired['{}_euclidean'.format(sig)]).values

# %%
calc_healthy_mean = pd.Series(summed_healthy_mean, index=select_healthy.index)
calc_healthy_mean_nan = calc_healthy_mean.reindex(results_healthy.index)
calc_healthy_mean = calc_healthy_mean.reindex(results_healthy.index, fill_value=100000)
calc_impaired_mean = pd.Series(summed_impaired_mean, index=select_impaired.index)
calc_impaired_mean_nan = calc_impaired_mean.reindex(results_impaired.index)
calc_impaired_mean = calc_impaired_mean.reindex(results_impaired.index, fill_value=100000)

# %%
results_healthy['NRMSE_range']= results_healthy['NRMSE'].values
results_impaired['NRMSE_range']= results_impaired['NRMSE'].values

# %%
results_healthy['NRMSE'] = calc_healthy_mean_nan.values
results_healthy.to_csv(healthy_pfile)
results_healthy['NRMSE'] = calc_healthy_mean.values

results_impaired['NRMSE'] = calc_impaired_mean_nan.values
results_impaired.to_csv(impaired_pfile)
results_impaired['NRMSE'] = calc_impaired_mean.values

# %%
euc_index=select_healthy['euclidean'].sort_values().index

# %%
healthy_mean_index=calc_healthy_mean.sort_values().index

# %%
impaired_mean_index=calc_impaired_mean.sort_values().index

# %%
results_healthy
# Out:
#         idx       r_m        v_pn  sigma_coll      p_tot       r_t   Vol_mit  \
# ix
# 0         0  0.025560   92.993624   74.734504  24.851663  0.021499  0.068050
# 1         1  0.022651   64.428950   69.395677  24.808854  0.019783  0.096109
# 2         2  0.014253  113.107739   37.934726  20.904676  0.012001  0.077518
# 3         3  0.034945   87.194227   58.854034  17.606359  0.024212  0.096656
# 4         4  0.013804   61.452712   83.674069  10.140384  0.017317  0.069896
# 5         5  0.014526  120.759973   49.021755  25.457961  0.017560  0.098965
# 6         6  0.034307   71.445392   38.857713  20.811854  0.017514  0.059186
# 7         7  0.039266   76.655064   33.579920  10.325817  0.021237  0.083622
# 8         8  0.027267   95.027785   67.722271  18.777703  0.012978  0.091483
# 9         9  0.029518  109.533678   41.253048  20.963956  0.014981  0.096407
# 10       10  0.024212   79.748953   33.385416  13.569507  0.022580  0.061868
# ...

# %%
results_impaired.columns
# Out:
# Index(['idx', 'r_m', 'v_pn', 'sigma_coll', 'p_tot', 'r_t', 'Vol_mit',
#        'cytox_tot_tis', 'r_0', 'v_cn', 'T_max0', 'Xtot', 'Dp_n', 'a_n',
#        'K_sigma', 'R_autp', 'K_G', 'k_aut', 'euclidean', 'manhattan', 'MSE',
#        'RMSE', 'NRMSE', 'MAE', 'Vmca_euclidean', 'Vmca_manhattan', 'Vmca_MSE',
#        'Vmca_RMSE', 'Vmca_NRMSE', 'Vmca_MAE', 'CCO_euclidean', 'CCO_manhattan',
#        'CCO_MSE', 'CCO_RMSE', 'CCO_NRMSE', 'CCO_MAE', 'TOI_euclidean',
#        'TOI_manhattan', 'TOI_MSE', 'TOI_RMSE', 'TOI_NRMSE', 'TOI_MAE', 'Batch',
#        'NRMSE_old'],
#       dtype='object')

# %%
fig, ax = plt.subplots(1)
ax.plot(range(100), euc_index[:100], label='euclidean')
ax.plot(range(100), nrmse_mean_index[:100], label='nrmse')
ax.plot(range(100), nrmse_rng_index[:100], label='nrmse')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-91dd6daf3976> in <module>()
#       1 fig, ax = plt.subplots(1)
#       2 ax.plot(range(100), euc_index[:100], label='euclidean')
# ----> 3 ax.plot(range(100), nrmse_mean_index[:100], label='nrmse')
#       4 ax.plot(range(100), nrmse_rng_index[:100], label='nrmse')
#
# NameError: name 'nrmse_mean_index' is not defined

# %%
results = pd.concat([results_healthy, results_impaired])

# %%
ar_state = ['Healthy'] * results_healthy.shape[0]
ar_state.extend(['Impaired'] * results_healthy.shape[0])
results['Autoregulatory State'] = ar_state
results['Autoregulatory State'] = results['Autoregulatory State'].astype('category')

# %%
results.columns
# Out:
# Index(['idx', 'r_m', 'v_pn', 'sigma_coll', 'p_tot', 'r_t', 'Vol_mit',
#        'cytox_tot_tis', 'r_0', 'v_cn', 'T_max0', 'Xtot', 'Dp_n', 'a_n',
#        'K_sigma', 'R_autp', 'K_G', 'k_aut', 'euclidean', 'manhattan', 'MSE',
#        'RMSE', 'NRMSE', 'MAE', 'Vmca_euclidean', 'Vmca_manhattan', 'Vmca_MSE',
#        'Vmca_RMSE', 'Vmca_NRMSE', 'Vmca_MAE', 'CCO_euclidean', 'CCO_manhattan',
#        'CCO_MSE', 'CCO_RMSE', 'CCO_NRMSE', 'CCO_MAE', 'TOI_euclidean',
#        'TOI_manhattan', 'TOI_MSE', 'TOI_RMSE', 'TOI_NRMSE', 'TOI_MAE', 'Batch',
#        'NRMSE_old', 'Autoregulatory State'],
#       dtype='object')

# %%
d = "NRMSE"
figPath = "/home/buck06191/Dropbox/phd/Bayesian_fitting/{}/{}/{}/"\
    "Figures/{}".format(model_name, 'PLOS_paper', 'Comparison', d+"_mean")

dir_util.mkpath(figPath)

lim = 1000
limit = lim
groups = results['Autoregulatory State'].unique()
acceptance_param=1
group_names= groups

# %%
df_list = [results_healthy, results_impaired]
p_names = list(params.keys())

kde_dfs = []
for ii, df in enumerate(df_list):
    sorted_df = df.sort_values(by=d)

    if limit:
        accepted_limit = limit
    elif frac:
        accepted_limit = frac_calculator(sorted_df, frac)
    else:
        raise ValueError('No limit or fraction given.')

    sorted_df['Accepted'] = np.zeros(len(sorted_df))
    sorted_df['Accepted'].iloc[:accepted_limit] = 1
    sorted_df.loc[:, 'Accepted'][sorted_df[d] == 100000] = 2

    kde_dfs.append(sorted_df.loc[(sorted_df['Accepted'] == acceptance_param), :])
    kde_dfs[ii]['Group'] = [ii] * accepted_limit

kde_df = pd.concat(kde_dfs)

if group_names:
    kde_df['Group']= kde_df['Group'].map(lambda x: "{}".format(group_names[x]))
groups = kde_df['Group'].unique()
colors = sns.color_palette("hls", len(groups))
color_pal = dict(zip(groups, colors))
# Out:
# /home/buck06191/.virtualenvs/python3/lib/python3.6/site-packages/pandas/core/indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /home/buck06191/.virtualenvs/python3/lib/python3.6/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/buck06191/.virtualenvs/python3/lib/python3.6/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# %matplotlib inline
# g = sns.PairGrid(
#             kde_df,
#             vars=p_names,
#             hue="Group",
#             hue_kws={"cmap":['Blues', 'Reds']},
#             palette=color_pal,
#             diag_sharey=False)
# g.map_diag(sns.distplot)
# g.map_lower(sns.kdeplot)

# %%
comparison_kde_plot(df_list, params, group_names=list(groups), limit=lim, n_ticks=4, d=d,
                 median_file=os.path.join(figPath, "medians.txt"))
# Out:
# /home/buck06191/.virtualenvs/python3/lib/python3.6/site-packages/pandas/core/indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# ../bayescmd/results_handling.py:732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   sorted_df.loc[:, 'Accepted'][sorted_df[d] == 100000] = 2
# ../bayescmd/results_handling.py:736: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...
